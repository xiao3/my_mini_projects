# %% [markdown]
# # 上海疫情地图

# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Map

# %%
# input data
df_input = pd.read_excel('../data/shanghai_20200207.xlsx')
df_input
# Out:
#      地区名  确诊人数
# 0   浦东新区    50
# 1    宝山区    16
# 2    徐汇区    15
# 3    静安区    14
# 4    闵行区    12
# 5    长宁区    11
# 6    松江区    10
# 7    奉贤区     9
# 8    普陀区     7
# 9    虹口区     7
# 10   杨浦区     7
# 11   黄浦区     5
# 12   嘉定区     5
# 13   青浦区     5
# 14   金山区     2
# 15   崇明区     2

# %%
districts = df_input['地区名'].tolist()
value = df_input['确诊人数'].tolist()
max_value = max(value)
min_value = min(value)

# %%
# Define map info:

my_mark = "确诊地区"
my_city = "上海"
my_title = "新型冠状病毒感染肺炎上海疫情地图"
my_subtitle = "截至2020年2月7日  绘制：xxx"
my_output_path_1 = "../output/shanghai-map-1.html"
my_output_path_2 = "../output/shanghai-map-2.html"


c = (
        Map(init_opts=opts.InitOpts(width ='1000px', height='1000px'))
        .add(my_mark, [list(z) for z in zip(districts, value)], my_city)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=True))
        .set_global_opts(
            title_opts=opts.TitleOpts(title=my_title, subtitle=my_subtitle),
            visualmap_opts=opts.VisualMapOpts(min_=min_value, 
                                              max_=max_value,
                                              #is_piecewise=True,
                                             ),
        )
    )


c.render(path=my_output_path_1)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="b6200b25f3f14383af78f15830f7d834" style="width:1000px; height:1000px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_b6200b25f3f14383af78f15830f7d834 = echarts.init(
#                     document.getElementById('b6200b25f3f14383af78f15830f7d834'), 'white', {renderer: 'canvas'});
#                 var option_b6200b25f3f14383af78f15830f7d834 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u786e\u8bca\u5730\u533a",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u4e0a\u6d77",
#             "data": [
#                 {
#                     "name": "\u6d66\u4e1c\u65b0\u533a",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u5f90\u6c47\u533a",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u9759\u5b89\u533a",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u957f\u5b81\u533a",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u6768\u6d66\u533a",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u9ec4\u6d66\u533a",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5609\u5b9a\u533a",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u9752\u6d66\u533a",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5d07\u660e\u533a",
#                     "value": 2
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u5730\u533a"
#             ],
#             "selected": {
#                 "\u786e\u8bca\u5730\u533a": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u65b0\u578b\u51a0\u72b6\u75c5\u6bd2\u611f\u67d3\u80ba\u708e\u4e0a\u6d77\u75ab\u60c5\u5730\u56fe",
#             "subtext": "\u622a\u81f32020\u5e742\u67087\u65e5  \u7ed8\u5236\uff1axxx",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 2,
#         "max": 50,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_b6200b25f3f14383af78f15830f7d834.setOption(option_b6200b25f3f14383af78f15830f7d834);
#         });
#     </script>

# %%
# define bins
#my_pieces = [
#      {"min": 30, "label": ">30", "color": "#8B1A1A"}, 
#      {"min": 11, "max": 30, "label": "11-30", "color": "#CD3333"},
#      {"min": 5, "max": 10, "label": "6-10", "color": "#FF6347"},
#      {"max": 5, "label": "1-5", "color": "#FFA07A"}   
#        ]

# define map info
#output_path = "../output/shanghai-2.html"

# create map
#map = Map(title, subtitle, width=1000, height=1000)
#map.add("确诊地区",
#        districts, value, maptype=maptype_name, 
#        is_visualmap=True,  
#        is_piecewise=True,
#        visual_text_color="#000",
#        visual_range_text=["", ""],
#        pieces=my_pieces,
#        is_label_show=True,
#        )
#map.render(path=output_path)
